# %%
import requests
import pandas as pd
import numpy as np
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## OMNI

# %% [markdown]
# ### Scrape Omni restaurants

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://www.google.com/maps/d/u/0/viewer?mid=1qN2EGFpFtGzVtUVAwiP74IFJPMX59pu2&ll=33.72331810000003%2C-117.789675&z=8'
driver.get(url)
data = []
# wait for options and select restaurants
restaurants = WebDriverWait(driver,5).until(
    EC.visibility_of_all_elements_located((By.CLASS_NAME, "HzV7m-pbTTYe-SmKAyb-haAclf")))[-1]
#click dropdown menu and find all restaurant links
restaurants.find_element(By.CLASS_NAME, 'HzV7m-pbTTYe-KoToPc-ornU0b').click()
time.sleep(1)
restaurants = restaurants.find_elements(By.CLASS_NAME, 'HzV7m-pbTTYe-ibnC6b-V67aGc')
print(f'found {len(restaurants)} restaurants')
# for each restaurant, save name, click to reveal address and save address
for r in restaurants[1:]:
    name = r.text
    r.click()
    try:
        address = WebDriverWait(driver,1).until(
            EC.visibility_of_all_elements_located((By.CLASS_NAME, "fO2voc-jRmmHf-MZArnb-Q7Zjwb")))[0].text
    except:
        webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
        continue
    data.append([name,address])

    webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
# Close the webdriver
driver.quit()
# Out:
# found 63 restaurants

# %%
omni_df = pd.DataFrame(data, columns=['name','address'])
omni_df
# Out:
#                                            name  \
# 0                                     Veg'n Out
# 1                                        Kenshō
# 2          Goldilocks Filipino Cuisine (SFO T1)
# 3                                    Veggie Fam
# 4                                       Kau Kau
# 5                              Lee's Sandwiches
# 6                              Lee's Sandwiches
# 7                           Yu Seafood Yorkdale
# 8                                 Bring Me Some
# 9   MATHILDA'S - Plant-based eating at its best
# 10                Shanghai Wonderful Restaurant
# 11                                      Do Chay
# 12                                     Old Bird
# 13                            Mott 32 Vancouver
# 14                                 Saigon Lotus
# 15                         Stacks Pancake House
# 16                         Stacks Pancake House
# 17                         Stacks Pancake House
# 18                         Stacks Pancake House
# 19          aloha Stacks Island Eatery & Bakery
# 20                         Stacks Pancake House
# 21                              Scramblers Cafe
# 22        Plumeria Cafe by Stacks Pancake House
# 23                        Umami Ramen & Izakaya
# 24                        Choo Choo Train Sushi
# 25                        L&L Hawaiian Barbecue
# 26                        L&L Hawaiian Barbecue
# 27                        L&L Hawaiian Barbecue
# 28                                L&L Drive-Inn
# 29                        L&L Hawaiian Barbecue
# 30                        L&L Hawaiian Barbecue
# 31                        L&L Hawaiian Barbecue
# 32              L&L Hawaiian Barbecue, Tumwater
# 33                                          PAI
# 34                                   PAI Uptown
# 35                  Juicy Dumpling in Chinatown
# 36                                     Mama Dut
# 37                    La Fabrique & Bar à Gyoza
#
#                                               address
# 0          4606 Mission Gorge Pl, San Diego, CA 92120
# 1            16511 Magnolia St, Westminster, CA 92683
# 2   San Francisco International Airport-T1 Harvey ...
# 3      1500 Griffith Park Blvd, Los Angeles, CA 90189
# 4           855 57th St Suite C, Sacramento, CA 95819
# 5            2471 Berryessa Rd #3, San Jose, CA 95133
# 6            260 E Santa Clara St, San Jose, CA 95113
# 7   3401 Dufferin St Unit 601A, Toronto, ON M6A 2T...
# 8     638 Concession St, Hamilton, ON L8V 1B5, Canada
# 9          29 Simcoe St S, Oshawa, ON L1H 4G1, Canada
# 10   9260 Bridgeport Rd, Richmond, BC V6X 1S1, Canada
# 11       1392 Kingsway, Vancouver, BC V5V 3E4, Canada
# 12        3950 Main St, Vancouver, BC V5V 3P2, Canada
# 13   1161 W Georgia St, Vancouver, BC V6E 0C6, Canada
# 14        6 St Andrew St, Toronto, ON M5T 1K6, Canada
# 15                  14421 Culver Dr, Irvine, CA 92604
# 16     27680 Marguerite Pkwy, Mission Viejo, CA 92692
# 17                   34255 CA-1, Dana Point, CA 92629
# 18            1330 Bison Ave, Newport Beach, CA 92660
# 19                 11461 South St, Cerritos, CA 90703
# 20  27760 Santa Margarita Pkwy, Mission Viejo, CA ...
# 21               3699 Hamner Ave # C, Norco, CA 92860
# 22  23811 Aliso Creek Rd STE 122, Laguna Niguel, C...
# 23       6660 Rue Clark, Montréal, QC H2S 3E7, Canada
# 24                    374 Broad Ave, Leonia, NJ 07605
# 25              550 Paiea St #132, Honolulu, HI 96819
# 26               1100 Ward Ave #5, Honolulu, HI 96814
# 27  Inside Walmart, 710 Ke’eaumoku St #100, Honolu...
# 28     41-1610 Kalanianaʻole Hwy, Waimanalo, HI 96795
# 29           14310 Culver Dr Unit A, Irvine, CA 92604
# 30       7127 Hollister Ave Ste. 21, Goleta, CA 93117
# 31                   356 Broadway, El Cajon, CA 92021
# 32          5312 Littlerock Rd SW, Tumwater, WA 98512
# 33          18 Duncan St, Toronto, ON M5H 3G8, Canada
# 34         2335 Yonge St, Toronto, ON M4P 2E6, Canada
# 35      280 Spadina Ave., Toronto, ON M5T 0A1, Canada
# 36            1414 SE Morrison St, Portland, OR 97214
# 37  1909 Avenue du Mont-Royal E, Montréal, QC H2H ...

# %% [markdown]
# ### Get place Ids

# %%
#key api key
with open('/Users/alexanderdaffara/Documents/api_info/ImpactRestaurantSearch/Impact_maps_api_key.txt', 'r') as f:
    key = f.readline()
pids = []
# Iterate over the restaurants and retrieve their Place IDs
for name, address in zip(omni_df.name, omni_df.address):
    # URL for Place Search API
    url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={name} {address}&inputtype=textquery&fields=place_id&key={key}'

    # Send a GET request to the API endpoint
    response = requests.get(url)

    # Check if the response was successful (HTTP status code 200)
    if response.status_code == 200:
        # Convert the response to JSON format
        data = response.json()

        # Extract the Place ID from the response
        if data['status'] == 'OK':
            place_id = data['candidates'][0]['place_id']
            pids.append(place_id)
        else:
            print(f'Request for {name} succeeded with status {data["status"]}')
            pids.append(np.nan)
    else:
        # Print an error message if the response was unsuccessful
        print(f'Request for {name} failed with error code {response.status_code}')
        pids.append(np.nan)
omni_df['pid'] = pids
# Out:
# Request for Lee's Sandwiches succeeded with status REQUEST_DENIED
# Request for Scramblers Cafe succeeded with status REQUEST_DENIED
# Request for L&L Hawaiian Barbecue succeeded with status REQUEST_DENIED
# Request for L&L Hawaiian Barbecue succeeded with status REQUEST_DENIED
# Request for L&L Hawaiian Barbecue succeeded with status REQUEST_DENIED

# %% [markdown]
# ### Get place details

# %%
#key api key
with open('/Users/alexanderdaffara/Documents/api_info/ImpactRestaurantSearch/Impact_maps_api_key.txt', 'r') as f:
    key = f.readline()

place_details = reset_place_details()

# Iterate over the restaurants and retrieve their Place IDs
for name, pid in zip(omni_df.name, omni_df.pid):
    url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={pid}&key={key}"

    response = requests.request("GET", url)

    # Check if the response was successful (HTTP status code 200)
    if response.status_code == 200:
        # Convert the response to JSON format
        data = response.json()

        # Extract the Place ID from the response
        if data['status'] == 'OK':
            place_details = update_place_details(place_details, data['result'])
        else:
            print(f'Request for {name}, {pid} succeeded with status {data["status"]}')
            place_details = update_place_details(place_details, None)
    else:
        # Print an error message if the response was unsuccessful
        print(f'Request for {name}, {pid} failed with error code {response.status_code}')
        place_details = update_place_details(place_details, None)

# %% [markdown]
# #### merge Scraping df and place details df

# %%
merged_df = omni_df.merge(pd.DataFrame(place_details, columns=place_details.keys()).drop(columns=['name']),
                          how='inner',
                          left_on='pid',
                          right_on='place_id',
                          suffixes=['_omni','_google'])
merged_df.rename(columns={'opening_hours/weekday_text':'opening_hours', 'editorial_summary/overview': 'editorial_summary'}, inplace=True)
merged_df
# Out:
#                                            name  \
# 0                                     Veg'n Out
# 1                                        Kenshō
# 2          Goldilocks Filipino Cuisine (SFO T1)
# 3                                    Veggie Fam
# 4                                       Kau Kau
# 5                              Lee's Sandwiches
# 6                              Lee's Sandwiches
# 7                           Yu Seafood Yorkdale
# 8                                 Bring Me Some
# 9   MATHILDA'S - Plant-based eating at its best
# 10                Shanghai Wonderful Restaurant
# 11                                      Do Chay
# 12                                     Old Bird
# 13                            Mott 32 Vancouver
# 14                                 Saigon Lotus
# 15                         Stacks Pancake House
# 16                         Stacks Pancake House
# 17                         Stacks Pancake House
# 18                         Stacks Pancake House
# 19          aloha Stacks Island Eatery & Bakery
# 20                         Stacks Pancake House
# 21                              Scramblers Cafe
# 22        Plumeria Cafe by Stacks Pancake House
# 23                        Umami Ramen & Izakaya
# 24                        Choo Choo Train Sushi
# 25                        L&L Hawaiian Barbecue
# 26                        L&L Hawaiian Barbecue
# 27                        L&L Hawaiian Barbecue
# 28                                L&L Drive-Inn
# 29                                L&L Drive-Inn
# 30                                L&L Drive-Inn
# 31                                L&L Drive-Inn
# 32                                L&L Drive-Inn
# 33                        L&L Hawaiian Barbecue
# 34                        L&L Hawaiian Barbecue
# 35                        L&L Hawaiian Barbecue
# 36                        L&L Hawaiian Barbecue
# 37                        L&L Hawaiian Barbecue
# 38                        L&L Hawaiian Barbecue
# 39                        L&L Hawaiian Barbecue
# 40                        L&L Hawaiian Barbecue
# 41                        L&L Hawaiian Barbecue
# 42                        L&L Hawaiian Barbecue
# 43                        L&L Hawaiian Barbecue
# 44                        L&L Hawaiian Barbecue
# 45                        L&L Hawaiian Barbecue
# 46                        L&L Hawaiian Barbecue
# 47                        L&L Hawaiian Barbecue
# 48              L&L Hawaiian Barbecue, Tumwater
# 49              L&L Hawaiian Barbecue, Tumwater
# 50              L&L Hawaiian Barbecue, Tumwater
# 51              L&L Hawaiian Barbecue, Tumwater
# 52              L&L Hawaiian Barbecue, Tumwater
# 53                                          PAI
# 54                                   PAI Uptown
# 55                  Juicy Dumpling in Chinatown
# 56                                     Mama Dut
NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 29             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 30             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 31             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 32             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 33             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 34             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 35             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 36             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 37             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 38             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 39             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 40             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 41             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 42             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 43             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 44             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 45             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 46             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 47             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 48             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 49             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 50             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 51             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 52             NaN  [Monday: Open 24 hours, Tuesday: Open 24 hours...
# 53             NaN  [Monday: 4:00 – 9:00 PM, Tuesday: 12:00 – 9:00...
# 54             NaN  [Monday: 4:00 – 9:30 PM, Tuesday: 11:30 AM – 9...
# 55             NaN  [Monday: 11:00 AM – 9:00 PM, Tuesday: 11:00 AM...
# 56             NaN  [Monday: Closed, Tuesday: Closed, Wednesday: C...
# 57             NaN  [Monday: 7:00 AM – 7:00 PM, Tuesday: 7:00 AM –...
#
#    delivery dine_in                                  editorial_summary  ...  \
# 0      True    True                                                NaN  ...
# 1      True    True  Plentiful plates of plant-based sushi are on o...  ...
# 2     False    True  Down-to-earth pit stop for noodles, rice dishe...  ...
# 3      True    True                                                NaN  ...
# 4      True    True                                                NaN  ...
# 5      True    True  Counter-service chain for Vietnamese staples s...  ...
# 6      True    True  Counter-service chain for Vietnamese staples s...  ...
# 7      True    True                                                NaN  ...
# 8      True    True                                                NaN  ...
# 9       NaN    True  Laid-back counter-serve doling out pasta, sand...  ...
# 10     True    True                                                NaN  ...
# 11     True    True  Industrial-style restaurant offering vegetaria...  ...
# 12     True    True  Noodles, dumplings & other Chinese staples, pl...  ...
# 13    False    True  High-end restaurant featuring innovative Chine...  ...
# 14     True    True  Simple tables adorn this Vietnamese & Thai res...  ...
# 15     True    True  Popular daytime spot known for specialty panca...  ...
# 16     True    True  Popular daytime spot known for specialty panca...  ...
# 17     True    True  Popular daytime spot known for specialty panca...  ...
# 18     True    True  Popular daytime spot known for specialty panca...  ...
# 19     True    True                                                NaN  ...
# 20     True    True  Popular daytime spot known for specialty panca...  ...
# 21     True    True  Bright, low-key standby with sidewalk seats fo...  ...
# 22     True    True  Chill outpost of a cafe chain offering a menu ...  ...
# 23     True    True  Casual spot offering classic sushi, sashimi & ...  ...
# 24     True    True                                                NaN  ...
# 25     True    True  Island-themed fast-food chain whose menu featu...  ...
# 26     True    True  Island-themed fast-food chain whose menu featu...  ...
# 27     True    True  Island-themed fast-food chain whose menu featu...  ...
# 28      NaN     NaN                                                NaN  ...
# 29      NaN     NaN                                                NaN  ...
# 30      NaN     NaN                                                NaN  ...
# 31      NaN     NaN                                                NaN  ...
# 32      NaN     NaN                                                NaN  ...
# 33      NaN     NaN                                                NaN  ...
# 34      NaN     NaN                                                NaN  ...
# 35      NaN     NaN                                                NaN  ...
# 36      NaN     NaN                                                NaN  ...
# 37      NaN     NaN                                                NaN  ...
# 38      NaN     NaN                                                NaN  ...
# 39      NaN     NaN                                                NaN  ...
# 40      NaN     NaN                                                NaN  ...
# 41      NaN     NaN                                                NaN  ...
# 42      NaN     NaN                                                NaN  ...
# 43      NaN     NaN                                                NaN  ...
# 44      NaN     NaN                                                NaN  ...
# 45      NaN     NaN                                                NaN  ...
# 46      NaN     NaN                                                NaN  ...
# 47      NaN     NaN                                                NaN  ...
# 48      NaN     NaN                                                NaN  ...
# 49      NaN     NaN                                                NaN  ...
# 50      NaN     NaN                                                NaN  ...
# 51      NaN     NaN                                                NaN  ...
# 52      NaN     NaN                                                NaN  ...
# 53     True    True  Nuit & Jeff Regular's casual Northern Thai spo...  ...
# 54     True    True  Contemporary kitchen turning out salads, curri...  ...
# 55     True    True  Compact counter serve offering Shanghai-style ...  ...
# 56     True    True  Vietnamese-inspired veggie plates served in a ...  ...
# 57     True     NaN  This NYC outpost of a Swedish bakery chain ser...  ...
#
#     serves_lunch  serves_vegetarian_food serves_wine takeout type  \
# 0           True                    True       False    True  NaN
# 1           True                    True         NaN    True  NaN
# 2           True                    True        True    True  NaN
# 3           True                    True         NaN    True  NaN
# 4           True                     NaN        True    True  NaN
# 5           True                    True       False    True  NaN
# 6           True                    True         NaN    True  NaN
# 7           True                    True        True    True  NaN
# 8           True                    True       False    True  NaN
# 9           True                    True       False    True  NaN
# 10          True                     NaN        True    True  NaN
# 11          True                    True        True    True  NaN
# 12          True                    True        True    True  NaN
# 13          True                    True        True    True  NaN
# 14          True                    True        True    True  NaN
# 15          True                     NaN       False    True  NaN
# 16          True                     NaN       False    True  NaN
# 17          True                    True       False    True  NaN
# 18          True                     NaN         NaN    True  NaN
# 19          True                     NaN       False    True  NaN
# 20          True                     NaN         NaN    True  NaN
# 21          True                     NaN       False    True  NaN
# 22          True                    True        True    True  NaN
# 23          True                     NaN         NaN    True  NaN
# 24          True                     NaN         NaN    True  NaN
# 25          True                   False       False    True  NaN
# 26           NaN                   False       False    True  NaN
# 27          True                   False       False    True  NaN
# 28           NaN                     NaN         NaN     NaN  NaN
# 29           NaN                     NaN         NaN     NaN  NaN
# 30           NaN                     NaN         NaN     NaN  NaN
# 31           NaN                     NaN         NaN     NaN  NaN
# 32           NaN                     NaN         NaN     NaN  NaN
# 33           NaN                     NaN         NaN     NaN  NaN
# 34           NaN                     NaN         NaN     NaN  NaN
# 35           NaN                     NaN         NaN     NaN  NaN
# 36           NaN                     NaN         NaN     NaN  NaN
# 37           NaN                     NaN         NaN     NaN  NaN
# 38           NaN                     NaN         NaN     NaN  NaN
# 39           NaN                     NaN         NaN     NaN  NaN
# 40           NaN                     NaN         NaN     NaN  NaN
# 41           NaN                     NaN         NaN     NaN  NaN
# 42           NaN                     NaN         NaN     NaN  NaN
# 43           NaN                     NaN         NaN     NaN  NaN
# 44           NaN                     NaN         NaN     NaN  NaN
# 45           NaN                     NaN         NaN     NaN  NaN
# 46           NaN                     NaN         NaN     NaN  NaN
# 47           NaN                     NaN         NaN     NaN  NaN
# 48           NaN                     NaN         NaN     NaN  NaN
# 49           NaN                     NaN         NaN     NaN  NaN
# 50           NaN                     NaN         NaN     NaN  NaN
# 51           NaN                     NaN         NaN     NaN  NaN
# 52           NaN                     NaN         NaN     NaN  NaN
# 53          True                    True        True    True  NaN
# 54          True                    True        True    True  NaN
# 55          True                    True         NaN    True  NaN
# 56          True                    True       False    True  NaN
# 57           NaN                     NaN         NaN    True  NaN
#
#                                                 types  \
# 0   [restaurant, point_of_interest, food, establis...
# 1   [restaurant, food, point_of_interest, establis...
# 2   [cafe, bakery, bar, store, restaurant, point_o...
# 3   [restaurant, point_of_interest, food, establis...
# 4   [restaurant, point_of_interest, food, establis...
# 5   [restaurant, food, point_of_interest, establis...
# 6   [restaurant, food, point_of_interest, establis...
# 7   [restaurant, point_of_interest, food, establis...
# 8   [restaurant, point_of_interest, food, establis...
# 9   [restaurant, point_of_interest, food, establis...
# 10  [restaurant, food, point_of_interest, establis...
# 11  [restaurant, point_of_interest, food, establis...
# 12  [restaurant, bar, food, point_of_interest, est...
# 13  [bar, restaurant, food, point_of_interest, est...
# 14  [restaurant, food, point_of_interest, establis...
# 15  [restaurant, point_of_interest, food, establis...
# 16  [restaurant, point_of_interest, food, establis...
# 17  [bakery, meal_takeaway, restaurant, food, poin...
# 18  [restaurant, food, point_of_interest, establis...
# 19  [restaurant, food, point_of_interest, establis...
# 20  [restaurant, point_of_interest, food, establis...
# 21  [restaurant, food, point_of_interest, establis...
# 22  [restaurant, food, point_of_interest, establis...
# 23  [restaurant, food, point_of_interest, establis...
# 24  [restaurant, food, point_of_interest, establis...
# 25  [restaurant, point_of_interest, food, establis...
# 26  [restaurant, food, point_of_interest, establis...
# 27  [restaurant, point_of_interest, food, establis...
# 28  [convenience_store, grocery_or_supermarket, fo...
# 29  [convenience_store, grocery_or_supermarket, st...
# 30  [convenience_store, grocery_or_supermarket, st...
# 31  [convenience_store, grocery_or_supermarket, st...
# 32  [convenience_store, grocery_or_supermarket, st...
# 33  [convenience_store, grocery_or_supermarket, fo...
# 34  [convenience_store, grocery_or_supermarket, st...
# 35  [convenience_store, grocery_or_supermarket, st...
# 36  [convenience_store, grocery_or_supermarket, st...
# 37  [convenience_store, grocery_or_supermarket, st...
# 38  [convenience_store, grocery_or_supermarket, fo...
# 39  [convenience_store, grocery_or_supermarket, st...
# 40  [convenience_store, grocery_or_supermarket, st...
# 41  [convenience_store, grocery_or_supermarket, st...
# 42  [convenience_store, grocery_or_supermarket, st...
# 43  [convenience_store, grocery_or_supermarket, fo...
# 44  [convenience_store, grocery_or_supermarket, st...
# 45  [convenience_store, grocery_or_supermarket, st...
# 46  [convenience_store, grocery_or_supermarket, st...
# 47  [convenience_store, grocery_or_supermarket, st...
# 48  [convenience_store, grocery_or_supermarket, fo...
# 49  [convenience_store, grocery_or_supermarket, st...
# 50  [convenience_store, grocery_or_supermarket, st...
# 51  [convenience_store, grocery_or_supermarket, st...
# 52  [convenience_store, grocery_or_supermarket, st...
# 53  [restaurant, food, point_of_interest, establis...
# 54  [restaurant, food, point_of_interest, establis...
# 55  [restaurant, point_of_interest, food, establis...
# 56  [restaurant, point_of_interest, food, establis...
# 57  [bakery, food, store, point_of_interest, estab...
#
#                                                   url user_ratings_total  \
# 0    https://maps.google.com/?cid=3228831394100459681                 50
# 1   https://maps.google.com/?cid=13443983670162488561                282
# 2    https://maps.google.com/?cid=5276889313698002654                111
# 3    https://maps.google.com/?cid=4270479987264314382                  2
# 4   https://maps.google.com/?cid=13322888318211057912                 98
# 5    https://maps.google.com/?cid=1289244276935681731                396
# 6   https://maps.google.com/?cid=14603690811586745442                745
# 8                       http://www.bringmesome.ca/
# 9                         http://www.mathildas.ca/
# 10                                             NaN
# 11                               http://dochay.ca/
# 12                          http://www.oldbird.ca/
# 13               https://www.mott32.com/vancouver/
# 14              https://www.saigonlotustoronto.ca/
# 15                  http://stackspancakehouse.com/
# 16              http://www.stackspancakehouse.com/
# 17                  http://stackspancakehouse.com/
# 18                  http://stackspancakehouse.com/
# 19                  http://stackspancakehouse.com/
# 20                 https://stackspancakehouse.com/
# 21                      http://scramblerscafe.com/
# 22  https://www.facebook.com/PlumeriaCafebyStacks/
# 23                   https://www.umamisushi50.com/
# 24                  http://choochootrainsushi.com/
# 25               https://www.hawaiianbarbecue.com/
# 26               https://www.hawaiianbarbecue.com/
# 27          https://www.hawaiianbarbecue.com/menu/
# 28                                             NaN
# 29                                             NaN
# 30                                             NaN
# 31                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 35                                             NaN
# 36                                             NaN
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
# 42                                             NaN
# 43                                             NaN
# 44                                             NaN
# 45                                             NaN
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
# 50                                             NaN
# 51                                             NaN
# 52                                             NaN
# 53                      http://www.paitoronto.com/
# 54                         https://paitoronto.com/
# 55                    http://www.juicydumpling.ca/
# 56                        https://www.mamadut.com/
# 57                      http://fabriquebakery.com/
#
#    wheelchair_accessible_entrance
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                            True
# 8                            True
# 9                             NaN
# 10                           True
# 11                           True
# 12                           True
# 13                           True
# 14                          False
# 15                           True
# 16                           True
# 17                           True
# 18                           True
# 19                           True
# 20                           True
# 21                           True
# 22                           True
# 23                           True
# 24                            NaN
# 25                           True
# 26                           True
# 27                           True
# 28                           True
# 29                           True
# 30                           True
# 31                           True
# 32                           True
# 33                           True
# 34                           True
# 35                           True
# 36                           True
# 37                           True
# 38                           True
# 39                           True
# 40                           True
# 41                           True
# 42                           True
# 43                           True
# 44                           True
# 45                           True
# 46                           True
# 47                           True
# 48                           True
# 49                           True
# 50                           True
# 51                           True
# 52                           True
# 53                          False
# 54                            NaN
# 55                           True
# 56                           True
# 57                           True
#
# [58 rows x 27 columns]

# %% [markdown]
# #### Add zipcode column

# %%
zipcodes = pd.Series([addr.split() for addr in merged_df.address]).map(lambda x: x[-1] if x[-1] != 'Canada' else x[-3] + ' ' + x[-2][:-1])
merged_df['zipcode'] = zipcodes

# %% [markdown]
# #### Save data to csv

# %%
merged_df.to_csv('data/omni_place_details.tsv', sep='\t')

# %%
merged_df
# Out:
#                                            name  \
# 0                                     Veg'n Out
# 1                                        Kenshō
# 2          Goldilocks Filipino Cuisine (SFO T1)
# 3                                    Veggie Fam
# 4                                       Kau Kau
# 5                              Lee's Sandwiches
# 6                              Lee's Sandwiches
# 7                           Yu Seafood Yorkdale
# 8                                 Bring Me Some
# 9   MATHILDA'S - Plant-based eating at its best
# 10                Shanghai Wonderful Restaurant
# 11                                      Do Chay
# 12                                     Old Bird
# 13                            Mott 32 Vancouver
# 14                                 Saigon Lotus
# 15                         Stacks Pancake House
# 16                         Stacks Pancake House
# 17                         Stacks Pancake House
# 18                         Stacks Pancake House
# 19          aloha Stacks Island Eatery & Bakery
# 20                         Stacks Pancake House
# 12     True    True  Noodles, dumplings & other Chinese staples, pl...  ...
# 13    False    True  High-end restaurant featuring innovative Chine...  ...
# 14     True    True  Simple tables adorn this Vietnamese & Thai res...  ...
# 15     True    True  Popular daytime spot known for specialty panca...  ...
# 16     True    True  Popular daytime spot known for specialty panca...  ...
# 17     True    True  Popular daytime spot known for specialty panca...  ...
# 18     True    True  Popular daytime spot known for specialty panca...  ...
# 19     True    True                                                NaN  ...
# 20     True    True  Popular daytime spot known for specialty panca...  ...
# 21     True    True  Bright, low-key standby with sidewalk seats fo...  ...
# 22     True    True  Chill outpost of a cafe chain offering a menu ...  ...
# 23     True    True  Casual spot offering classic sushi, sashimi & ...  ...
# 24     True    True                                                NaN  ...
# 25     True    True  Island-themed fast-food chain whose menu featu...  ...
# 26     True    True  Island-themed fast-food chain whose menu featu...  ...
# 27     True    True  Island-themed fast-food chain whose menu featu...  ...
# 28      NaN     NaN                                                NaN  ...
# 29      NaN     NaN                                                NaN  ...
# 30      NaN     NaN                                                NaN  ...
# 31      NaN     NaN                                                NaN  ...
# 32      NaN     NaN                                                NaN  ...
# 33      NaN     NaN                                                NaN  ...
# 34      NaN     NaN                                                NaN  ...
# 35      NaN     NaN                                                NaN  ...
# 36      NaN     NaN                                                NaN  ...
# 37      NaN     NaN                                                NaN  ...
# 38      NaN     NaN                                                NaN  ...
# 39      NaN     NaN                                                NaN  ...
# 40      NaN     NaN                                                NaN  ...
# 41      NaN     NaN                                                NaN  ...
# 42      NaN     NaN                                                NaN  ...
# 43      NaN     NaN                                                NaN  ...
# 44      NaN     NaN                                                NaN  ...
# 45      NaN     NaN                                                NaN  ...
# 46      NaN     NaN                                                NaN  ...
# 47      NaN     NaN                                                NaN  ...
# 48      NaN     NaN                                                NaN  ...
# 49      NaN     NaN                                                NaN  ...
# 50      NaN     NaN                                                NaN  ...
# 51      NaN     NaN                                                NaN  ...
# 52      NaN     NaN                                                NaN  ...
# 53     True    True  Nuit & Jeff Regular's casual Northern Thai spo...  ...
# 54     True    True  Contemporary kitchen turning out salads, curri...  ...
# 55     True    True  Compact counter serve offering Shanghai-style ...  ...
# 56     True    True  Vietnamese-inspired veggie plates served in a ...  ...
# 57     True     NaN  This NYC outpost of a Swedish bakery chain ser...  ...
#
#     serves_lunch  serves_vegetarian_food serves_wine takeout type  \
# 0           True                    True       False    True  NaN
# 1           True                    True         NaN    True  NaN
# 2           True                    True        True    True  NaN
# 3           True                    True         NaN    True  NaN
# 4           True                     NaN        True    True  NaN
# 5           True                    True       False    True  NaN
# 6           True                    True         NaN    True  NaN
# 7           True                    True        True    True  NaN
# 8           True                    True       False    True  NaN
# 9           True                    True       False    True  NaN
# 10          True                     NaN        True    True  NaN
# 11          True                    True        True    True  NaN
# 12          True                    True        True    True  NaN
# 13          True                    True        True    True  NaN
# 14          True                    True        True    True  NaN
# 15          True                     NaN       False    True  NaN
# 16          True                     NaN       False    True  NaN
# 17          True                    True       False    True  NaN
# 18          True                     NaN         NaN    True  NaN
# 19          True                     NaN       False    True  NaN
# 20          True                     NaN         NaN    True  NaN
# 21          True                     NaN       False    True  NaN
# 22          True                    True        True    True  NaN
# 23          True                     NaN         NaN    True  NaN
# 24          True                     NaN         NaN    True  NaN
# 25          True                   False       False    True  NaN
# 26           NaN                   False       False    True  NaN
# 27          True                   False       False    True  NaN
# 28           NaN                     NaN         NaN     NaN  NaN
# 29           NaN                     NaN         NaN     NaN  NaN
# 30           NaN                     NaN         NaN     NaN  NaN
# 31           NaN                     NaN         NaN     NaN  NaN
# 32           NaN                     NaN         NaN     NaN  NaN
# 33           NaN                     NaN         NaN     NaN  NaN
# 34           NaN                     NaN         NaN     NaN  NaN
# 35           NaN                     NaN         NaN     NaN  NaN
# 36           NaN                     NaN         NaN     NaN  NaN
# 37           NaN                     NaN         NaN     NaN  NaN
# 38           NaN                     NaN         NaN     NaN  NaN
# 39           NaN                     NaN         NaN     NaN  NaN
# 40           NaN                     NaN         NaN     NaN  NaN
# 41           NaN                     NaN         NaN     NaN  NaN
# 42           NaN                     NaN         NaN     NaN  NaN
# 43           NaN                     NaN         NaN     NaN  NaN
# 44           NaN                     NaN         NaN     NaN  NaN
# 45           NaN                     NaN         NaN     NaN  NaN
# 46           NaN                     NaN         NaN     NaN  NaN
# 47           NaN                     NaN         NaN     NaN  NaN
# 48           NaN                     NaN         NaN     NaN  NaN
# 49           NaN                     NaN         NaN     NaN  NaN
# 50           NaN                     NaN         NaN     NaN  NaN
# 51           NaN                     NaN         NaN     NaN  NaN
# 52           NaN                     NaN         NaN     NaN  NaN
# 53          True                    True        True    True  NaN
# 54          True                    True        True    True  NaN
# 55          True                    True         NaN    True  NaN
# 56          True                    True       False    True  NaN
# 57           NaN                     NaN         NaN    True  NaN
#
#                                                 types  \
# 0   [restaurant, point_of_interest, food, establis...
# 1   [restaurant, food, point_of_interest, establis...
# 2   [cafe, bakery, bar, store, restaurant, point_o...
# 3   [restaurant, point_of_interest, food, establis...
# 4   [restaurant, point_of_interest, food, establis...
# 5   [restaurant, food, point_of_interest, establis...
# 6   [restaurant, food, point_of_interest, establis...
# 7   [restaurant, point_of_interest, food, establis...
# 8   [restaurant, point_of_interest, food, establis...
# 9   [restaurant, point_of_interest, food, establis...
# 10  [restaurant, food, point_of_interest, establis...
# 11  [restaurant, point_of_interest, food, establis...
# 12  [restaurant, bar, food, point_of_interest, est...
# 13  [bar, restaurant, food, point_of_interest, est...
# 14  [restaurant, food, point_of_interest, establis...
# 15  [restaurant, point_of_interest, food, establis...
# 16  [restaurant, point_of_interest, food, establis...
# 17  [bakery, meal_takeaway, restaurant, food, poin...
# 18  [restaurant, food, point_of_interest, establis...
# 19  [restaurant, food, point_of_interest, establis...
# 20  [restaurant, point_of_interest, food, establis...
# 21  [restaurant, food, point_of_interest, establis...
# 22  [restaurant, food, point_of_interest, establis...
# 23  [restaurant, food, point_of_interest, establis...
# 24  [restaurant, food, point_of_interest, establis...
# 25  [restaurant, point_of_interest, food, establis...
# 26  [restaurant, food, point_of_interest, establis...
# 27  [restaurant, point_of_interest, food, establis...
# 28  [convenience_store, grocery_or_supermarket, fo...
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# 5                            True
# 6                            True
# 7                            True
# 8                            True
# 9                             NaN
# 10                           True
# 11                           True
# 12                           True
# 13                           True
# 14                          False
# 15                           True
# 16                           True
# 17                           True
# 18                           True
# 19                           True
# 20                           True
# 21                           True
# 22                           True
# 23                           True
# 24                            NaN
# 25                           True
# 26                           True
# 27                           True
# 28                           True
# 29                           True
# 30                           True
# 31                           True
# 32                           True
# 33                           True
# 34                           True
# 35                           True
# 36                           True
# 37                           True
# 38                           True
# 39                           True
# 40                           True
# 41                           True
# 42                           True
# 43                           True
# 44                           True
# 45                           True
# 46                           True
# 47                           True
# 48                           True
# 49                           True
# 50                           True
# 51                           True
# 52                           True
# 53                          False
# 54                            NaN
# 55                           True
# 56                           True
# 57                           True
#
# [58 rows x 27 columns]

# %% [markdown]
# ## Current Foods

# %% [markdown]
# ### Scrape restaurant Data
# get restaurants from current foods

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = 'https://currentfoods.com/find-us/'
driver.get(url)

# wait for searchfield and send "SAN "
search_field = WebDriverWait(driver,10).until(
    EC.visibility_of_all_elements_located((By.CLASS_NAME, 'storerocket-search-field')))
search_field[0].send_keys('SAN ')

# wait for autocomplete results and press ENTER
WebDriverWait(driver,10).until(
    EC.visibility_of_all_elements_located((By.CLASS_NAME, 'storerocket-autocomplete-result')))
search_field[0].send_keys(Keys.RETURN)

# wait for availability of searchbox clear button and press it
clear_btn = WebDriverWait(driver,10).until(
    EC.element_to_be_clickable((By.CLASS_NAME, 'storerocket-clear-search'))).click()

# wait for all possible list results to appear and save their text content in names
names_selector = WebDriverWait(driver, 10).until(
    EC.visibility_of_all_elements_located((By.CLASS_NAME, 'storerocket-result-content'))
)
names = [name.text.split('\n') for name in names_selector]

# Close the webdriver
driver.quit()

# %%
df = pd.DataFrame(names, columns=['name','addr_1','addr_2','country','phone'])
df.head()
# Out:
#             name                       addr_1                        addr_2  \
# 0  7Friday Sushi  18121 TUCKERTON RD, STE 100          CYPRESS, TEXAS 77433
# 1        Bel Air              1286 STABLER LN   YUBA CITY, CALIFORNIA 95993
# 2        Bel Air              3250 ARENA BLVD  SACRAMENTO, CALIFORNIA 95834
# 3        Bel Air             5100 LAGUNA BLVD   ELK GROVE, CALIFORNIA 95758
# 4        Bel Air     8425 ELK GROVE FLORIN RD   ELK GROVE, CALIFORNIA 95624
#
#                     country           phone
# 0  UNITED STATES OF AMERICA  (281) 304-2646
# 1  UNITED STATES OF AMERICA            None
# 2  UNITED STATES OF AMERICA            None
# 3  UNITED STATES OF AMERICA            None
# 4  UNITED STATES OF AMERICA            None

# %% [markdown]
# ### Get place Ids
# Populate df with place ids from google Places API

# %%
#key api key
with open('/Users/alexanderdaffara/Documents/api_info/ImpactRestaurantSearch/Impact_maps_api_key.txt', 'r') as f:
    key = f.readline()
pids = []
# Iterate over the restaurants and retrieve their Place IDs
for name, address in zip(df.name, df.addr_1):
    # URL for Place Search API
    url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={name} {address}&inputtype=textquery&fields=place_id&key={key}'

    # Send a GET request to the API endpoint
    response = requests.get(url)

    # Check if the response was successful (HTTP status code 200)
    if response.status_code == 200:
        # Convert the response to JSON format
        data = response.json()

        # Extract the Place ID from the response
        if data['status'] == 'OK':
            place_id = data['candidates'][0]['place_id']
            pids.append(place_id)
        else:
            print(f'Request for {name} succeeded with status {data["status"]}')
            pids.append(np.nan)
    else:
        # Print an error message if the response was unsuccessful
        print(f'Request for {name} failed with error code {response.status_code}')
        pids.append(np.nan)
df['pid'] = pids
# Out:
# Request for La Sirena - ARGENTONA succeeded with status ZERO_RESULTS
# Request for La Sirena - BCN-ANDREA DÒRIA succeeded with status ZERO_RESULTS
# Request for La Sirena - CERVERA succeeded with status ZERO_RESULTS
# Request for La Sirena - CORNELLÀ-1 succeeded with status ZERO_RESULTS
# Request for La Sirena - ESPLUGUES DE LLOBREGAT-1 succeeded with status ZERO_RESULTS
# Request for La Sirena - GIRONA-3 succeeded with status ZERO_RESULTS
# Request for La Sirena - L'HOSPITALET-3 succeeded with status ZERO_RESULTS
# Request for La Sirena - L'HOSPITALET-4 succeeded with status ZERO_RESULTS
# Request for La Sirena - L'HOSPITALET-6 succeeded with status ZERO_RESULTS
# Request for La Sirena - L'HOSPITALET-7 succeeded with status ZERO_RESULTS
# Request for La Sirena - MAD-AMOR DE DIOS succeeded with status ZERO_RESULTS
# Request for La Sirena - MAD-JULIÁN ROMEA succeeded with status ZERO_RESULTS
# Request for La Sirena - MAD-MAGALLANES succeeded with status ZERO_RESULTS
# Request for La Sirena - MAD-MENÉNDEZ PELAYO succeeded with status ZERO_RESULTS
# Request for La Sirena - MAD-SANTA ENGRACIA succeeded with status ZERO_RESULTS
# Request for La Sirena - MATARÓ-1 succeeded with status ZERO_RESULTS
# Request for La Sirena - SABADELL-6 succeeded with status ZERO_RESULTS
# Request for La Sirena - SANT BOI DE LLOBREGAT-2 succeeded with status ZERO_RESULTS
# Request for La Sirena - SANT BOI DE LLOBREGAT-3 succeeded with status ZERO_RESULTS
# Request for La Sirena - SANTA COLOMA DE GRAMENET-3 succeeded with status ZERO_RESULTS
# Request for La Sirena - VIC-1 succeeded with status ZERO_RESULTS
# Request for La Sirena - VIC-2 succeeded with status ZERO_RESULTS
# Request for Ma-Kin Vegan Sushi succeeded with status REQUEST_DENIED
# Request for Pop Together succeeded with status ZERO_RESULTS
# Request for Raley's succeeded with status REQUEST_DENIED
# Request for SeaDog Sushi Bar succeeded with status REQUEST_DENIED

# %%
# df with pid's and dropped duplicates and pid nans
df.head()
# Out:
#             name                       addr_1                        addr_2  \
# 0  7Friday Sushi  18121 TUCKERTON RD, STE 100          CYPRESS, TEXAS 77433
# 1        Bel Air              1286 STABLER LN   YUBA CITY, CALIFORNIA 95993
# 2        Bel Air              3250 ARENA BLVD  SACRAMENTO, CALIFORNIA 95834
# 3        Bel Air             5100 LAGUNA BLVD   ELK GROVE, CALIFORNIA 95758
# 4        Bel Air     8425 ELK GROVE FLORIN RD   ELK GROVE, CALIFORNIA 95624
#
#                     country           phone                          pid
# 0  UNITED STATES OF AMERICA  (281) 304-2646  ChIJK7_f5VnXQIYR-0Ozp_9oxMA
# 1  UNITED STATES OF AMERICA            None  ChIJR-wdqV6rhIARybGPafx54CI
# 2  UNITED STATES OF AMERICA            None  ChIJYzyH9wbWmoAR0Etx8rf7k8o
# 3  UNITED STATES OF AMERICA            None  ChIJNWhGYyfGmoARNrnQscNDE3o
# 4  UNITED STATES OF AMERICA            None  ChIJN7RrprjGmoARgbOv2QruCqU

# %% [markdown]
# ### Get place details
# populate place_details_df with place details corresponding to the retrieved place Ids

# %%
# Empty place details
def reset_place_details():
    return {"place_id" : [],
            "business_status" : [],
            "curbside_pickup" : [],
            "opening_hours/weekday_text" : [],
            "delivery"  : [],
            "dine_in" : [],
            "editorial_summary/overview" : [],
            "name" : [],
            "price_level" : [],
            "rating" : [],
            "reservable" : [],
            "serves_beer" : [],
            "serves_breakfast" : [],
            "serves_brunch" : [],
            "serves_dinner" : [],
            "serves_lunch" : [],
            "serves_vegetarian_food" : [],
            "serves_wine" : [],
            "takeout" : [],
            "type" : [],
            "types" : [],
            "url" : [],
            "user_ratings_total" : [],
            "website" : [],
            "wheelchair_accessible_entrance" : [] }

# %%
# helper to add row of place details to dictionary
def update_place_details(pdt, data):
    if not data:
        for detail in list(pdt.keys()):
            pdt[detail].append(np.nan)
    else:
        long_details = ["opening_hours/weekday_text", "editorial_summary/overview"]
        details = set(list(pdt.keys())) - set(long_details)
        for detail in details:
            pdt[detail].append(data.get(detail,np.nan))
        for detail in long_details:
            d0, d1 = detail.split('/')
            pdt[detail].append(data.get(d0,{}).get(d1,np.nan))
        
    return pdt

# %%
#key api key
with open('/Users/alexanderdaffara/Documents/api_info/ImpactRestaurantSearch/Impact_maps_api_key.txt', 'r') as f:
    key = f.readline()

place_details = reset_place_details()

# Iterate over the restaurants and retrieve their Place IDs
for name, pid in zip(df.name, df.pid):
    url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={pid}&key={key}"

    response = requests.request("GET", url)

    # Check if the response was successful (HTTP status code 200)
    if response.status_code == 200:
        # Convert the response to JSON format
        data = response.json()

        # Extract the Place ID from the response
        if data['status'] == 'OK':
            place_details = update_place_details(place_details, data['result'])
        else:
            print(f'Request for {name}, {pid} succeeded with status {data["status"]}')
            place_details = update_place_details(place_details, None)
    else:
        # Print an error message if the response was unsuccessful
        print(f'Request for {name}, {pid} failed with error code {response.status_code}')
        place_details = update_place_details(place_details, None)
# Out:
# Request for Pop Together, ChIJBRk5eXR_j4ARM1axwk9nbpk succeeded with status NOT_FOUND

# %%
place_details_df = pd.DataFrame(place_details, columns=place_details.keys())
place_details_df.head()
# Out:
#                       place_id business_status curbside_pickup  \
# 0  ChIJK7_f5VnXQIYR-0Ozp_9oxMA     OPERATIONAL            True
# 1  ChIJR-wdqV6rhIARybGPafx54CI     OPERATIONAL            True
# 2  ChIJYzyH9wbWmoAR0Etx8rf7k8o     OPERATIONAL            True
# 3  ChIJNWhGYyfGmoARNrnQscNDE3o     OPERATIONAL            True
# 4  ChIJN7RrprjGmoARgbOv2QruCqU     OPERATIONAL            True
#
#                           opening_hours/weekday_text delivery dine_in  \
# 0  [Monday: 7:00 AM – 7:00 PM, Tuesday: 7:00 AM –...     True    True
# 1  [Monday: 6:00 AM – 11:00 PM, Tuesday: 6:00 AM ...     True   False
# 2  [Monday: 6:00 AM – 11:00 PM, Tuesday: 6:00 AM ...     True     NaN
# 3  [Monday: 6:00 AM – 11:00 PM, Tuesday: 6:00 AM ...     True   False
# 4  [Monday: 6:00 AM – 11:00 PM, Tuesday: 6:00 AM ...     True   False
#
#   editorial_summary/overview           name  price_level  rating  ...  \
# 0                        NaN  7Friday Sushi          NaN     5.0  ...
# 1                        NaN        Bel Air          2.0     4.3  ...
# 2                        NaN        Bel Air          2.0     4.4  ...
# 3                        NaN        Bel Air          2.0     4.3  ...
# 4                        NaN        Bel Air          2.0     4.3  ...
#
#   serves_lunch serves_vegetarian_food serves_wine takeout type  \
# 0         True                   True         NaN    True  NaN
# 1          NaN                    NaN         NaN    True  NaN
# 2          NaN                    NaN         NaN    True  NaN
# 3          NaN                    NaN         NaN    True  NaN
# 4          NaN                    NaN         NaN    True  NaN
#
#                                                types  \
# 0  [restaurant, point_of_interest, food, establis...
# 1  [grocery_or_supermarket, food, store, point_of...
# 2  [grocery_or_supermarket, store, food, point_of...
# 3  [grocery_or_supermarket, food, store, point_of...
# 4  [grocery_or_supermarket, food, store, point_of...
#
#                                                  url user_ratings_total  \
# 0  https://maps.google.com/?cid=13890342597956944891              136.0
# 1   https://maps.google.com/?cid=2513142717082481097             1238.0
# 2  https://maps.google.com/?cid=14597287584703007696             1031.0
# 3   https://maps.google.com/?cid=8796449004965640502              690.0
# 4  https://maps.google.com/?cid=11892579496394470273             1371.0
#
#                                              website  \
# 0                       http://www.7fridaysushi.com/
# 1  https://www.raleys.com/stores/bel-air-stabler-...
# 2                             http://www.raleys.com/
# 3  https://www.raleys.com/stores/bel-air-laguna-e...
# 4  https://www.raleys.com/stores/bel-air-elk-grov...
#
#    wheelchair_accessible_entrance
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
# [5 rows x 25 columns]

# %% [markdown]
# #### merge Scraping df with Place Details df

# %%
merged_df = df.merge(place_details_df.drop(columns='name'),
                     how='inner',
                     left_on='pid',
                     right_on='place_id',
                     suffixes=['_L','_R'])
merged_df.rename(columns={'opening_hours/weekday_text':'opening_hours', 'editorial_summary/overview': 'editorial_summary'}, inplace=True)
merged_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[311], line 1
# ----> 1 merged_df = df.merge(place_details_df.drop(columns='name'),
#       2                      how='inner',
#       3                      left_on='pid',
#       4                      right_on='place_id',
#       5                      suffixes=['_L','_R'])
#       6 merged_df.rename(columns={'opening_hours/weekday_text':'opening_hours', 'editorial_summary/overview': 'editorial_summary'}, inplace=True)
#       7 merged_df.head()
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1179, in _MergeOperation._get_merge_keys(self)
#    1175 if lk is not None:
#    1176     # Then we're either Hashable or a wrong-length arraylike,
#    1177     #  the latter of which will raise
#    1178     lk = cast(Hashable, lk)
# -> 1179     left_keys.append(left._get_label_or_level_values(lk))
#    1180     join_names.append(lk)
#    1181 else:
#    1182     # work-around for merge_asof(left_index=True)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'pid'

# %%
# add zipcode column
zipcodes = [addr.split()[-1] for addr in merged_df.addr_2]
merged_df['zipcode'] = zipcodes

# # manual zipcode input for one row
merged_df.loc[df.pid == 'ChIJ95l0SeR7pBIRGysUsgq0HX0','zipcode'] = '08799'

# %% [markdown]
# #### Save data to csv

# %%
merged_df.to_csv('data/place_details.tsv', sep='\t')

# %% [markdown]
# # CF Extra Info

# %%
rest_df = pd.read_csv('data/cf_restaurants.tsv', sep='\t', index_col=0)
rest_df
# Out:
#                                         name  \
# 0                              7Friday Sushi
# 21                   Bestie's Vegan Paradise
# 22                                 blue pokē
# 23   Blue Sushi Sake Grill - Power and Light
# 24      Blue Sushi Sake Grill - Court Avenue
# ..                                       ...
# 502                             Sancha Sushi
# 503                             Sancha Sushi
# 504                         SeaDog Sushi Bar
# 506                Trader Vic's - Emeryville
# 510                            West of Pecos
#
#                                                    url  \
# 0    https://maps.google.com/?cid=13890342597956944891
# 21   https://maps.google.com/?cid=16874039323387828855
# 22   https://maps.google.com/?cid=13134429803069602710
# 23    https://maps.google.com/?cid=6359419975810682658
# 24    https://maps.google.com/?cid=8663256725197864751
# ..                                                 ...
# 502  https://maps.google.com/?cid=17639356127951289174
# 503   https://maps.google.com/?cid=1468585188584661767
# 504  https://maps.google.com/?cid=11997228980446377630
# 506  https://maps.google.com/?cid=16606159308439485126
# 510  https://maps.google.com/?cid=13089150326399156870
#
#                           addr_1                           addr_2  \
# 0    18121 TUCKERTON RD, STE 100             CYPRESS, TEXAS 77433
# 21             4882 FOUNTAIN AVE    LOS ANGELES, CALIFORNIA 90029
# 22    1325 E PLAZA BLVD, STE 103  NATIONAL CITY, CALIFORNIA 91950
# 23                 101 E 14TH ST      KANSAS CITY, MISSOURI 64106
# 24                 316 COURT AVE           DES MOINES, IOWA 50309
# ..                           ...                              ...
# 502               1224 GRANT AVE  SAN FRANCISCO, CALIFORNIA 94133
# 503                253 CHURCH ST  SAN FRANCISCO, CALIFORNIA 94114
# 504    1500 W DIVISION ST, #3344          CHICAGO, ILLINOIS 60642
# 506                  9 ANCHOR DR     EMERYVILLE, CALIFORNIA 94608
# 510              550 VALENCIA ST  SAN FRANCISCO, CALIFORNIA 94110
#
#                       country curbside_pickup delivery dine_in  price_level  \
# 0    UNITED STATES OF AMERICA            True     True    True          NaN
# 21   UNITED STATES OF AMERICA            True     True     NaN          NaN
# 22   UNITED STATES OF AMERICA            True     True    True          2.0
# 23   UNITED STATES OF AMERICA             NaN     True    True          2.0
# 24   UNITED STATES OF AMERICA             NaN     True    True          2.0
# ..                        ...             ...      ...     ...          ...
# 502  UNITED STATES OF AMERICA             NaN     True    True          NaN
# 503  UNITED STATES OF AMERICA             NaN     True    True          2.0
# 504  UNITED STATES OF AMERICA           False     True    True          2.0
# 506  UNITED STATES OF AMERICA            True    False    True          3.0
# 510  UNITED STATES OF AMERICA             NaN     True    True          2.0
#
#      rating  ... serves_lunch serves_vegetarian_food serves_wine takeout  \
# 0       5.0  ...         True                   True         NaN    True
# 21      4.5  ...          NaN                    NaN         NaN    True
# 22      4.6  ...         True                   True       False    True
# 23      4.9  ...         True                   True        True    True
# 24      4.5  ...         True                   True        True    True
# ..      ...  ...          ...                    ...         ...     ...
# 502     4.4  ...         True                    NaN         NaN    True
# 503     4.8  ...         True                    NaN        True    True
# 504     4.3  ...         True                   True        True    True
# 506     4.4  ...         True                   True        True    True
# 510     4.4  ...         True                   True        True    True
#
#     user_ratings_total wheelchair_accessible_entrance zipcode  \
# 0                136.0                           True   77433
# 21               225.0                           True   90029
# 22               594.0                           True   91950
# 23                37.0                           True   64106
# 24               656.0                           True   50309
# ..                 ...                            ...     ...
# 502               48.0                           True   94133
# 503               53.0                           True   94114
# 504              324.0                            NaN   60642
# 506             1139.0                           True   94608
# 510             1032.0                           True   94110
#
#                                      editorial_summary  \
# 0                                                  NaN
# 21                                                 NaN
# 22                                                 NaN
# 23   Modern, clubby restaurant featuring sushi & Ja...
# 24   Modern, clubby restaurant featuring sushi & Ja...
# ..                                                 ...
# 502                                                NaN
# 503                                                NaN
# 504  Brick-lined Japanese BYOB spot with a modern m...
# 506  Festive Polynesian-style fixture boasts creati...
# 510  Swinging saloon doors lead to chile-spiced, sm...
#
#                                                  types  \
# 0    ['restaurant', 'point_of_interest', 'food', 'e...
# 21   ['grocery_or_supermarket', 'meal_takeaway', 'r...
# 22   ['restaurant', 'point_of_interest', 'food', 'e...
# 23   ['restaurant', 'point_of_interest', 'food', 'e...
# 24   ['restaurant', 'food', 'point_of_interest', 'e...
# ..                                                 ...
# 502  ['restaurant', 'point_of_interest', 'food', 'e...
# 503  ['restaurant', 'point_of_interest', 'food', 'e...
# 504  ['veterinary_care', 'meal_takeaway', 'restaura...
# 506  ['bar', 'restaurant', 'food', 'point_of_intere...
# 510  ['bar', 'restaurant', 'food', 'point_of_intere...
#
#                                             categories
# 0                                                  NaN
# 21                                                 NaN
# 22                                                 NaN
# 23   Sushi Bars, Restaurants, Nightlife, Cocktail B...
# 24   Sushi Bars, Restaurants, Nightlife, Cocktail B...
# ..                                                 ...
# 502                                                NaN
# 503                                                NaN
# 504                                                NaN
# 506                                                NaN
# 510                                                NaN
#
# [99 rows x 25 columns]

# %% [markdown]
# ### Scrape GMaps for extra info

# %%
data = []
driver = webdriver.Chrome(ChromeDriverManager().install())

driver.get(rest_df.url.iloc[98])
# wait for options and select restaurants
WebDriverWait(driver,3).until(
    EC.visibility_of_element_located((By.CLASS_NAME, "y0K5Df"))).click() 
text= []
n = len(WebDriverWait(driver,3).until(
        EC.presence_of_all_elements_located((By.CLASS_NAME, "iP2t7d"))))
for i in range(n):
    text.append(WebDriverWait(driver,3).until(
        EC.presence_of_all_elements_located((By.CLASS_NAME, "iP2t7d")))[i].text)
this_data = {key: val for key, val in zip([s.split('\n')[0] for s in text], [s.split('\n')[1:] for s in text])}
data.append(this_data)
time.sleep(10)
print(f'{i}/99')
# Close the webdriver
driver.quit()
# Out:
# 10/99

# %%
d_is = []
counter = 33
while counter < 99:
    data = []
    try:
        for i, url in enumerate(rest_df.url[counter:]):
            driver = webdriver.Chrome(ChromeDriverManager().install())

            driver.get(url)
            # wait for options and select restaurants
            WebDriverWait(driver,3).until(
                EC.visibility_of_element_located((By.CLASS_NAME, "y0K5Df"))).click() 
            text= []
            n = len(WebDriverWait(driver,3).until(
                    EC.presence_of_all_elements_located((By.CLASS_NAME, "iP2t7d"))))
            for i in range(n):
                text.append(WebDriverWait(driver,3).until(
                    EC.presence_of_all_elements_located((By.CLASS_NAME, "iP2t7d")))[i].text)
            this_data = {key: val for key, val in zip([s.split('\n')[0] for s in text], [s.split('\n')[1:] for s in text])}
            data.append(this_data)
            time.sleep(10)
            print(f'{i}/99')
        counter = 99
        break
    except:
        i = len(data)
        if i == 0: 
            print("no new data")
            break
        d_i = pd.DataFrame(data)
        d_is.append(d_i)
        counter += i
        print(f'{i} new data points')
    finally:
        # Close the webdriver
        driver.quit()
        continue
# Out:
# 10/99
# 8/99
# 2 new data points
# 8/99
# 8/99
# 8/99
# 3 new data points
# 8/99
# 1 new data points
# no new data
# 8/99
# 1 new data points
# no new data
# no new data
# 8/99
# 1 new data points
# 8/99
# 8/99
# 8/99
# 8/99
# 4 new data points
# 8/99
# 1 new data points
# no new data
# 8/99
# 8/99
# 2 new data points
# 8/99
# 1 new data points
# 8/99
# 8/99
# 2 new data points
# 8/99
# 1 new data points
# no new data
# 8/99
# 8/99
# 8/99
# 8/99
# 4 new data points
# 8/99
# 1 new data points
# no new data
# 7/99
# 1 new data points
# no new data
# 8/99
# 8/99
# 8/99
# 8/99
# 8/99
# 8/99
# 8/99
# 7 new data points
# 8/99
# 8/99
# 2 new data points
# no new data
# no new data
# no new data
# 8/99
# 1 new data points
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# 8/99
# 8/99
# 8/99
# 3 new data points
# 8/99
# 1 new data points
# 8/99
# 8/99
# 2 new data points
# no new data
# no new data
# 8/99
# 8/99
# 8/99
# 3 new data points
# 8/99
# 8/99
# 8/99
# 3 new data points
# no new data
# no new data
# no new data
# 8/99
# 1 new data points
# no new data
# no new data
# no new data
# 8/99
# 8/99
# 8/99
# 3 new data points
# 8/99
# 1 new data points
# 8/99
# 1 new data points
# no new data
# no new data
# no new data
# no new data
# no new data
# 8/99
# 8/99
# 10/99
# 9/99
# 4 new data points
# 8/99
# 8/99
# 2 new data points
# 9/99
# 7/99
# 5/99
# 3 new data points
# 9/99
# 1 new data points
# no new data
# no new data
# no new data
# 10/99
# 1 new data points
# 11/99
# 10/99

# %%
final_google_df = pd.concat(*d_is).reset_index(inplace=True, drop=True)
final_google_df.to_csv('data/cf_restaurants_extra_data.tsv', sep='\t')
# Out:
#                                       Service options  \
# 0   [Curbside pickup, Drive-through, Takeout, Dine...
# 1   [Curbside pickup, No-contact delivery, Deliver...
# 2   [Curbside pickup, No-contact delivery, Deliver...
# 3                        [Delivery, Takeout, Dine-in]
# 4       [Outdoor seating, Delivery, Takeout, Dine-in]
# ..                                                ...
# 1                        [Delivery, Takeout, Dine-in]
# 2                        [Delivery, Takeout, Dine-in]
# 0                        [Delivery, Takeout, Dine-in]
# 0   [Outdoor seating, No-contact delivery, Deliver...
# 0   [Outdoor seating, No-contact delivery, Deliver...
#
#                                 Popular for  \
# 0              [Lunch, Dinner, Solo dining]
# 1                                       NaN
# 2              [Lunch, Dinner, Solo dining]
# 3              [Lunch, Dinner, Solo dining]
# 4              [Lunch, Dinner, Solo dining]
# ..                                      ...
# 1                                       NaN
# 2              [Lunch, Dinner, Solo dining]
# 0              [Lunch, Dinner, Solo dining]
# 0              [Lunch, Dinner, Solo dining]
# 0   [Breakfast, Lunch, Dinner, Solo dining]
#
#                                         Accessibility  \
# 0   [Wheelchair accessible entrance, Wheelchair ac...
# 1   [Wheelchair accessible entrance, Wheelchair ac...
# 2   [Wheelchair accessible entrance, Wheelchair ac...
# 3   [Wheelchair accessible entrance, Wheelchair ac...
# 4   [Wheelchair accessible entrance, Wheelchair ac...
# ..                                                ...
# 1                     [Wheelchair accessible seating]
# 2   [Wheelchair accessible entrance, Wheelchair ac...
# 0   [Wheelchair accessible entrance, Wheelchair ac...
# 0   [Wheelchair accessible restroom, Wheelchair ac...
# 0   [Wheelchair accessible entrance, Wheelchair ac...
#
#                                             Offerings  \
# 0   [Healthy options, Quick bite, Small plates, Ve...
# 1                  [Organic products, Prepared foods]
# 2   [Comfort food, Healthy options, Organic dishes...
# 3   [Alcohol, Beer, Cocktails, Happy hour drinks, ...
# 4   [Alcohol, Beer, Cocktails, Happy hour drinks, ...
# ..                                                ...
# 1   [Alcohol, Beer, Cocktails, Coffee, Hard liquor...
# 2         [Healthy options, Quick bite, Small plates]
# 0   [Alcohol, Beer, Healthy options, Small plates,...
# 0   [Healthy options, Vegan options, Vegetarian op...
# 0   [Alcohol, Beer, Cocktails, Coffee, Comfort foo...
#
#                                        Dining options  \
# 0                 [Breakfast, Lunch, Dinner, Dessert]
# 1                                                 NaN
# 2         [Lunch, Dinner, Catering, Dessert, Seating]
# 3         [Lunch, Dinner, Catering, Dessert, Seating]
# 4         [Lunch, Dinner, Catering, Dessert, Seating]
# ..                                                ...
# 1                         [Breakfast, Lunch, Dessert]
# 2                                     [Lunch, Dinner]
# 0                                     [Lunch, Dinner]
# 0         [Lunch, Dinner, Catering, Dessert, Seating]
# 0   [Breakfast, Brunch, Lunch, Dinner, Dessert, Se...
#
#                                             Amenities  \
# 0                           [Good for kids, Restroom]
# 1                                        [Free Wi-Fi]
# 2              [Good for kids, High chairs, Restroom]
# 3                                                 NaN
# 4                 [Bar onsite, High chairs, Restroom]
# ..                                                ...
# 1                [Bar onsite, Dogs allowed, Restroom]
# 2                                                 NaN
# 0                                          [Restroom]
# 0                             [High chairs, Restroom]
# 0   [Bar onsite, Gender-neutral restroom, High cha...
#
#                            Atmosphere  \
# 0                      [Casual, Cozy]
# 1                                 NaN
# 2                            [Casual]
# 3                            [Casual]
# 4   [Casual, Cozy, Romantic, Upscale]
# ..                                ...
# 1                            [Casual]
# 2                            [Casual]
# 0                            [Casual]
# 0            [Casual, Cozy, Romantic]
# 0                      [Casual, Cozy]
#
#                                              Planning  \
# 0                              [Accepts reservations]
# 1                                       [Quick visit]
# 2                                                 NaN
# 3                              [Accepts reservations]
# 4                              [Accepts reservations]
# ..                                                ...
# 1                              [Accepts reservations]
# 2                                                 NaN
# 0                              [Accepts reservations]
# 0   [Dinner reservations recommended, Accepts rese...
# 0   [Dinner reservations recommended, Accepts rese...
#
#                                              Payments  \
# 0    [Debit cards, NFC mobile payments, Credit cards]
# 1   [Debit cards, NFC mobile payments, SNAP/EBT, C...
# 2    [Debit cards, NFC mobile payments, Credit cards]
# 3    [Debit cards, NFC mobile payments, Credit cards]
# 4    [Debit cards, NFC mobile payments, Credit cards]
# ..                                                ...
# 1                                                 NaN
# 2                                                 NaN
# 0    [Debit cards, NFC mobile payments, Credit cards]
# 0                         [Debit cards, Credit cards]
# 0    [Debit cards, NFC mobile payments, Credit cards]
#
#                                                 Crowd  \
# 0                                                 NaN
# 1            [LGBTQ+ friendly, Transgender safespace]
# 2   [College students, Family-friendly, Groups, LG...
# 3                                                 NaN
# 4                                  [Groups, Tourists]
# ..                                                ...
# 1                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
# 0                           [Family-friendly, Groups]
# 0                [College students, Groups, Tourists]
#
#                       Recycling                           Highlights  \
# 0                           NaN                                  NaN
# 1   [Glass bottles, Metal cans]                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                       [Fast service]
# 4                           NaN  [Fast service, Great tea selection]
# ..                          ...                                  ...
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 0                           NaN                       [Fast service]
# 0                           NaN                [Great tea selection]
# 0                           NaN                       [Fast service]
#
#               From the business
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 1   [Identifies as women-owned]
# 2                           NaN
# 0                           NaN
# 0                           NaN
# 0                           NaN
#
# [99 rows x 13 columns]
